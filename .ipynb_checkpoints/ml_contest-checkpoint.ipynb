# %% [markdown]
# Посмотреть зависит ли успех от того учится ли человек по выходным.
# Равномерно проходившие курс и спуртами. Вообще глазками посмотреть отдельных людей
# Какой длины перерыв указывает на то, что не дойдет уже
# Интересны люди, бросившие на 80%?
# По графикам можно отличить не осиливших и не заинтересовавшихся?
# Окончившие всегда имеют хороший процент успешных сдач?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ___
# #### Исходные данные. Таблица 1 из 2. events_data

# %%
events_data = pd.read_csv('event_data_train_1.csv', header=0).\
                        append(pd.read_csv('event_data_train_2.csv', header=0))
df = events_data
df[::(df.shape[0] // 50)]
# Out:
#          step_id   timestamp           action  user_id
# 0          32815  1434340848           viewed    17632
# 69614      32809  1434552802       discovered     1108
# 139228     32930  1434991539       discovered     1179
# 208842     32174  1435331262           viewed     8852
# 278456     32953  1435663333           viewed     5377
# 348070     33537  1435963039           viewed    16238
# 417684     31991  1436193580           viewed    25601
# 487298     34027  1436459174           viewed     9610
# 556912     33733  1436809623           passed    17823
# 626526     33939  1437344298           viewed      783
# 696140     32173  1440621097           passed     2237
# 765754     32809  1445516176  started_attempt     9976
# 835368     33493  1448403737       discovered     8066
# 904982     33539  1452574883           viewed    20907
# 974596     31983  1455635427  started_attempt    15264
# 1044210    33984  1458744965           viewed    22580
# ...

# %% [markdown]
# *step_id* - id стэпа
# *user_id* - анонимизированный id юзера
# *timestamp* - время наступления события в формате unix date
# *action* - событие, возможные значения:
# + *discovered* - пользователь перешел на стэп
# + *viewed* - просмотр шага,
# + *started_attempt* - начало попытки решить шаг, ранее нужно было явно нажать на кнопку - начать решение, перед тем как приступить к решению практического шага
# + *passed* - удачное решение практического шага

# %%
print(f'df.shape: {df.shape}')
for column in df:
    print('_' * 100)
    print(column, 
          df[column].dtypes, 
          f'notNaN fraction - {df[column].notna().sum() / df.shape[0]}', 
          f'notNaN - {df[column].notna().sum()}', 
          f'nunique - {df[column].nunique()}', 
          sep='\n')
    if df[column].dtype in ('object', 'bool'):
        print(
            pd.concat(
                [df[column].value_counts(), 
                 df[column].value_counts() / df[column].notna().sum()],  # why don't work parameter dropna=True?
                axis=1)
        )
        print('    Share among the 10 most common:')
        df[column].value_counts().head(10).plot(kind='pie')
        plt.show()
    elif df[column].dtype in ('float64', 'int64'):  # how write 'all digital types'?
        print(
            pd.concat(
                [df[column].value_counts(bins=10), 
                 df[column].value_counts(bins=10) / df[column].notna().sum()],  # why don't work parameter dropna=True?
                axis=1)
        )
        df[column].hist(bins=100, log=True)
        plt.show()
# Out:
# df.shape: (3480703, 4)
# ____________________________________________________________________________________________________
# step_id
# int64
# notNaN fraction - 1.0
# notNaN - 3480703
# nunique - 198
#                       step_id   step_id
# (30328.022, 43253.7]  3408635  0.979295
# (120039.9, 132837.6]    47136  0.013542
# (145635.3, 158433.0]    20780  0.005970
# (107242.2, 120039.9]     4152  0.001193
# (132837.6, 145635.3]        0  0.000000
# (94444.5, 107242.2]         0  0.000000
# (81646.8, 94444.5]          0  0.000000
# (68849.1, 81646.8]          0  0.000000
# (56051.4, 68849.1]          0  0.000000
# (43253.7, 56051.4]          0  0.000000
# ____________________________________________________________________________________________________
# timestamp
# int64
# notNaN fraction - 1.0
# notNaN - 3480703
# nunique - 2196932
#                                 timestamp  timestamp
# (1434248416.036, 1443584044.3]     729454   0.209571
# ...

# %%
df.describe()
# Out:
#             step_id     timestamp       user_id
# count  3.480703e+06  3.480703e+06  3.480703e+06
# mean   3.487358e+04  1.480288e+09  1.331468e+04
# std    1.422243e+04  3.068906e+07  7.779099e+03
# min    3.045600e+04  1.434341e+09  1.000000e+00
# 25%    3.217900e+04  1.450271e+09  6.642000e+03
# 50%    3.292900e+04  1.483904e+09  1.320800e+04
# 75%    3.348100e+04  1.507889e+09  2.014400e+04
# max    1.584330e+05  1.526773e+09  2.679800e+04

# %%
df.corr()
# Out:
#            step_id  timestamp   user_id
# step_id    1.00000   0.100990 -0.001690
# timestamp  0.10099   1.000000 -0.020749
# user_id   -0.00169  -0.020749  1.000000

# %% [markdown]
# ___
# #### Исходные данные. Таблица 2 из 2. submissions_data

# %%
submissions_data = pd.read_csv('submissions_data_train.csv', header=0)
df = submissions_data
df[::(df.shape[0] // 50)]
# Out:
#         step_id   timestamp submission_status  user_id
# 0         31971  1434349275           correct    15853
# 10182     32810  1436201770             wrong    16791
# 20364     33334  1436056091           correct    25291
# 30546     32174  1434631569           correct     6334
# 40728     32795  1434984462             wrong    22022
# 50910     33731  1437298726           correct    23394
# 61092     32244  1436214491             wrong    20475
# 71274     33538  1436621589             wrong     9018
# 81456     32244  1435845051             wrong    11025
# 91638     33539  1436729394           correct     6777
# 101820    31981  1455094595           correct     8600
# 112002    33534  1477232551           correct    13303
# 122184    33350  1445522790             wrong     9976
# 132366    32206  1448211842             wrong    18457
# 142548    32244  1452698638             wrong    10534
# 152730    33334  1456315474             wrong     6854
# ...

# %% [markdown]
# *step_id* - id стэпа
# *timestamp* - время отправки решения в формате unix date
# *submission_status* - статус решения
# *user_id* - анонимизированный id юзера

# %%
print(f'df.shape: {df.shape}')
for column in df:
    print('_' * 100)
    print(column, 
          df[column].dtypes, 
          f'notNaN fraction - {df[column].notna().sum() / df.shape[0]}', 
          f'notNaN - {df[column].notna().sum()}', 
          f'nunique - {df[column].nunique()}', 
          sep='\n')
    if df[column].dtype in ('object', 'bool'):
        print(
            pd.concat(
                [df[column].value_counts(), 
                 df[column].value_counts() / df[column].notna().sum()],  # why don't work parameter dropna=True?
                axis=1)
        )
        print('    Share among the 10 most common:')
        df[column].value_counts().head(10).plot(kind='pie')
        plt.show()
    elif df[column].dtype in ('float64', 'int64'):  # how write 'all digital types'?
        print(
            pd.concat(
                [df[column].value_counts(bins=10), 
                 df[column].value_counts(bins=10) / df[column].notna().sum()],  # why don't work parameter dropna=True?
                axis=1)
        )
        df[column].hist(bins=100, log=True)
        plt.show()
# Out:
# df.shape: (509104, 4)
# ____________________________________________________________________________________________________
# step_id
# int64
# notNaN fraction - 1.0
# notNaN - 509104
# nunique - 76
#                       step_id   step_id
# (31882.225, 40848.4]   503289  0.988578
# (111867.6, 120745.0]     5815  0.011422
# (102990.2, 111867.6]        0  0.000000
# (94112.8, 102990.2]         0  0.000000
# (85235.4, 94112.8]          0  0.000000
# (76358.0, 85235.4]          0  0.000000
# (67480.6, 76358.0]          0  0.000000
# (58603.2, 67480.6]          0  0.000000
# (49725.8, 58603.2]          0  0.000000
# (40848.4, 49725.8]          0  0.000000
# ____________________________________________________________________________________________________
# timestamp
# int64
# notNaN fraction - 1.0
# notNaN - 509104
# nunique - 504343
#                                 timestamp  timestamp
# (1434248513.716, 1443583972.3]     110793   0.217624
# ...

# %%
df.describe()
# Out:
#              step_id     timestamp        user_id
# count  509104.000000  5.091040e+05  509104.000000
# mean    33732.591433  1.480582e+09   13198.874945
# std      9379.377465  3.097267e+07    7820.240678
# min     31971.000000  1.434341e+09       2.000000
# 25%     32031.000000  1.449950e+09    6431.000000
# 50%     32763.000000  1.484339e+09   13082.000000
# 75%     33481.000000  1.508326e+09   19985.000000
# max    120745.000000  1.526771e+09   26798.000000

# %%
df.corr()
# Out:
#             step_id  timestamp   user_id
# step_id    1.000000   0.063390 -0.001133
# timestamp  0.063390   1.000000 -0.016604
# user_id   -0.001133  -0.016604  1.000000

# %% [markdown]
# ___
# #### Преобразование дат в человекочитаемые

# %%
events_data['date'] = pd.to_datetime(events_data.timestamp, unit='s')
events_data['day'] = events_data.date.dt.date
events_data
# Out:
#          step_id   timestamp      action  user_id                date  \
# 0          32815  1434340848      viewed    17632 2015-06-15 04:00:48
# 1          32815  1434340848      passed    17632 2015-06-15 04:00:48
# 2          32815  1434340848  discovered    17632 2015-06-15 04:00:48
# 3          32811  1434340895  discovered    17632 2015-06-15 04:01:35
# 4          32811  1434340895      viewed    17632 2015-06-15 04:01:35
# ...          ...         ...         ...      ...                 ...
# 1480698    33375  1526772685      viewed    11677 2018-05-19 23:31:25
# 1480699    32815  1526772750      viewed     5198 2018-05-19 23:32:30
# 1480700    32815  1526772750  discovered     5198 2018-05-19 23:32:30
# 1480701    32815  1526772750      passed     5198 2018-05-19 23:32:30
# 1480702    33892  1526772811      viewed    18526 2018-05-19 23:33:31
#
#                 day
# 0        2015-06-15
# 1        2015-06-15
# 2        2015-06-15
# 3        2015-06-15
# ...

# %%
submissions_data['date'] = pd.to_datetime(submissions_data.timestamp, unit='s')
submissions_data['day'] = submissions_data.date.dt.date
submissions_data
# Out:
#         step_id   timestamp submission_status  user_id                date  \
# 0         31971  1434349275           correct    15853 2015-06-15 06:21:15
# 1         31972  1434348300           correct    15853 2015-06-15 06:05:00
# 2         31972  1478852149             wrong    15853 2016-11-11 08:15:49
# 3         31972  1478852164           correct    15853 2016-11-11 08:16:04
# 4         31976  1434348123             wrong    15853 2015-06-15 06:02:03
# ...         ...         ...               ...      ...                 ...
# 509099   120745  1501946959             wrong     2615 2017-08-05 15:29:19
# 509100   120745  1503059927           correct    13177 2017-08-18 12:38:47
# 509101   120745  1506348153             wrong    15253 2017-09-25 14:02:33
# 509102   120745  1523035316             wrong     1424 2018-04-06 17:21:56
# 509103   120745  1523382825             wrong     9422 2018-04-10 17:53:45
#
#                day
# 0       2015-06-15
# 1       2015-06-15
# ...

# %% [markdown]
# ###### разное

# %%
events_data.groupby('day').user_id.nunique().plot(figsize=(20,10));
# количество уникальных пользователей по дням

# %% [markdown]
# ___
# #### Создание дф Действия разных пользователей users_events_data

# %%
# сколько каких действий совершил каждый пользователь
users_events_data = events_data.pivot_table(index='user_id', 
                                           columns='action', 
                                           values='step_id', 
                                           aggfunc='count', 
                                           fill_value=0) \
                                .reset_index()
users_events_data
# Out:
# action  user_id  discovered  passed  started_attempt  viewed
# 0             1           1       0                0       1
# 1             2           9       9                2      10
# 2             3          91      87               30     192
# 3             5          11      11                4      12
# 4             7           1       1                0       1
# ...         ...         ...     ...              ...     ...
# 19229     26790           8       8                1       9
# 19230     26793           1       0                1       1
# 19231     26794          69      69               34     180
# 19232     26797          10      10                2      13
# 19233     26798          12      12                3      12
#
# [19234 rows x 5 columns]

# %%
# гистограммы по действиям разных типов
for column in users_events_data.loc[:, 'discovered':]:
    print(column)
    users_events_data[column].hist(bins=100).set_yscale('log')
    plt.show()
# Out:
# discovered
# passed
# started_attempt
# viewed

# %%
users_events_data.describe()
# Out:
# action       user_id    discovered        passed  started_attempt  \
# count   19234.000000  19234.000000  19234.000000     19234.000000
# mean    13363.573672     35.847718     33.811532        16.119736
# std      7750.057260     56.576201     54.932368        31.249011
# min         1.000000      0.000000      0.000000         0.000000
# 25%      6636.500000      1.000000      1.000000         0.000000
# 50%     13358.000000      9.000000      8.000000         2.000000
# 75%     20073.750000     42.000000     39.000000        15.000000
# max     26798.000000    198.000000    198.000000       721.000000
#
# action        viewed
# count   19234.000000
# mean       95.187169
# std       346.323327
# min         0.000000
# 25%         1.000000
# 50%        12.000000
# 75%        89.000000
# max     32778.000000

# %%
users_events_data[users_events_data.viewed < 1000].loc[:, 'discovered':].corr()
# корреляция между всеми показателями действий большая, если отбросить сотню человек, которые viewed больше 1 000 раз
# Out:
# action           discovered    passed  started_attempt    viewed
# action
# discovered         1.000000  0.995571         0.945950  0.900024
# passed             0.995571  1.000000         0.954877  0.897485
# started_attempt    0.945950  0.954877         1.000000  0.891261
# viewed             0.900024  0.897485         0.891261  1.000000

# %%
sns.pairplot(users_events_data[users_events_data.viewed < 1000].loc[:, 'discovered':]);

# %% [markdown]
# ___
# #### Создание дф Количество (не)успешных действий пользователей users_scores

# %%
# сколько (не)успешных сдач заданий совершил пользователь
users_scores = submissions_data.pivot_table(index='user_id', 
                                           columns='submission_status', 
                                           values='step_id', 
                                           aggfunc='count', 
                                           fill_value=0).reset_index()
users_scores
# Out:
# submission_status  user_id  correct  wrong
# 0                        2        2      0
# 1                        3       29     23
# 2                        5        2      2
# 3                        8        9     21
# 4                       14        0      1
# ...                    ...      ...    ...
# 9935                 26787        3      0
# 9936                 26790        1      0
# 9937                 26794       33      9
# 9938                 26797        2      0
# 9939                 26798        2      1
#
# [9940 rows x 3 columns]

# %%
# гистограмма количество пользователей, успешно сдавших за время обучения x заданий
users_scores[users_scores.correct < 101].correct.hist(bins=100);
# users_scores.correct.max()  # 421 успешную сдачу кто-то сделал
# users_scores.correct[users_scores.correct > 100].count()  #  больше 100 успешных сдач у 18 человек

# %%
# гистограмма количество пользователей, не успешно сдавших за время обучения x заданий
users_scores[users_scores.wrong < 101].wrong.hist(bins=100);

# %% [markdown]
# ___
# #### Создание серии Перерывы в занятиях gap_data

# %%
# довольно спорный подход из урока

# Берем только 3 столбца и выбираем только по одной строчке за день для каждого пользователя (верхнюю, вроде)
# группируем по пользователям и таймстемпы каждого пользователя
# складываем в список
# и вычисляем разницу между соседними таймстемпами пользователя (здесь выбросятся те, кто заходил один раз?)
# Берем только данные:  массив из кучи массивов (для каждого пользователя) с перерывами, которые делал юзер
gap_data = events_data[['user_id', 'day', 'timestamp']].drop_duplicates(subset=['user_id', 'day']) \
                                                        .groupby('user_id')['timestamp'] \
                                                        .apply(list) \
                                                        .apply(np.diff) \
                                                        .values

# сваливаем числа из подсписков в один единый список (теряя всю информацию об отдельных пользователях), 
# преобразуя данные в серию
gap_data = pd.Series(np.concatenate(gap_data, axis=0))

# переводим из секунд в сутки
gap_data = gap_data / (24 * 60 * 60)
gap_data
# Out:
# 0         56.060208
# 1         79.852419
# 2          2.112083
# 3          1.084606
# 4         32.047106
#             ...
# 97867    166.056586
# 97868      5.845613
# 97869      1.137176
# 97870      0.659942
# 97871     18.148032
# Length: 97872, dtype: float64

# %%
gap_data.hist(figsize=(12, 8), bins=100).set_yscale('log');

# %%
gap_data.quantile(0.90)
# Out:
# 18.325995370370403

# %%
gap_data.quantile(0.95)
# Out:
# 59.760440972222156

# %% [markdown]
# В 90% случаев ученики возвращаются в течение 18 дней, в 95% - 60 дней.
# ![](https://smallivingworld.ru/800/600/https/sun9-6.userapi.com/fQYArWK9Ate46N_nAg0s1UZMEUeMTZbhz9CbKQ/fYdl-Ou1eYk.jpg)
# Волюнтаристски взяли 30 дней как срок, по которому будем считать, что на курс ученик уже не вернется: drop_out_threshold

# %% [markdown]
# ___
# #### Создание дф Данные по пользователям users_data

# %%
users_data = events_data.groupby('user_id', as_index=False) \
                        .agg({'timestamp': 'max'}) \
                        .rename(columns={'timestamp': 'last_timestamp'})
users_data
# Out:
#        user_id  last_timestamp
# 0            1      1472827464
# 1            2      1519226966
# 2            3      1444581588
# 3            5      1499859939
# 4            7      1521634660
# ...        ...             ...
# 19229    26790      1517495987
# 19230    26793      1510225034
# 19231    26794      1512035039
# 19232    26797      1509995096
# 19233    26798      1520978742
#
# [19234 rows x 2 columns]

# %%
# время, когда выгрузили наши данные (последний таймстемп)
now = events_data.timestamp.max()
now
# Out:
# 1526772811

# %%
# срок 30 дней в секундах
drop_out_threshold = 30 * 24 * 60 * 60
drop_out_threshold
# Out:
# 2592000

# %%
# добавляем колонку: является ли пользователь покинувшим курс 
users_data['is_gone_user'] = (now - users_data.last_timestamp) > drop_out_threshold
users_data
# Out:
#        user_id  last_timestamp  is_gone_user
# 0            1      1472827464          True
# 1            2      1519226966          True
# 2            3      1444581588          True
# 3            5      1499859939          True
# 4            7      1521634660          True
# ...        ...             ...           ...
# 19229    26790      1517495987          True
# 19230    26793      1510225034          True
# 19231    26794      1512035039          True
# 19232    26797      1509995096          True
# 19233    26798      1520978742          True
#
# [19234 rows x 3 columns]

# %%
users_scores
# Out:
# submission_status  user_id  correct  wrong
# 0                        2        2      0
# 1                        3       29     23
# 2                        5        2      2
# 3                        8        9     21
# 4                       14        0      1
# ...                    ...      ...    ...
# 9935                 26787        3      0
# 9936                 26790        1      0
# 9937                 26794       33      9
# 9938                 26797        2      0
# 9939                 26798        2      1
#
# [9940 rows x 3 columns]

# %%
users_data = users_data.merge(users_scores, on='user_id', how='outer')
users_data
# Out:
#        user_id  last_timestamp  is_gone_user  correct  wrong
# 0            1      1472827464          True      NaN    NaN
# 1            2      1519226966          True      2.0    0.0
# 2            3      1444581588          True     29.0   23.0
# 3            5      1499859939          True      2.0    2.0
# 4            7      1521634660          True      NaN    NaN
# ...        ...             ...           ...      ...    ...
# 19229    26790      1517495987          True      1.0    0.0
# 19230    26793      1510225034          True      NaN    NaN
# 19231    26794      1512035039          True     33.0    9.0
# 19232    26797      1509995096          True      2.0    0.0
# 19233    26798      1520978742          True      2.0    1.0
#
# [19234 rows x 5 columns]

# %%
users_data = users_data.fillna(0)
users_data[::(users_data.shape[0] // 50)]
# Out:
#        user_id  last_timestamp  is_gone_user  correct  wrong
# 0            1      1472827464          True      0.0    0.0
# 384        535      1521549422          True      0.0    0.0
# 768       1030      1499094126          True      0.0    0.0
# 1152      1569      1505157817          True     13.0   32.0
# 1536      2115      1514552824          True      8.0   21.0
# 1920      2619      1523716189          True     15.0   30.0
# 2304      3148      1509523187          True     78.0  193.0
# 2688      3678      1478948375          True      0.0    0.0
# 3072      4215      1524835164         False     36.0   41.0
# 3456      4753      1513620114          True      2.0    0.0
# 3840      5305      1450094480          True      0.0    0.0
# 4224      5847      1476632237          True      8.0    8.0
# 4608      6358      1479473169          True      0.0    0.0
# 4992      6890      1492689260          True      0.0    0.0
# ...

# %%
users_data = users_data.merge(users_events_data, how='outer')
users_data[::(users_data.shape[0] // 50)]
# Out:
#        user_id  last_timestamp  is_gone_user  correct  wrong  discovered  \
# 0            1      1472827464          True      0.0    0.0           1
# 384        535      1521549422          True      0.0    0.0           1
# 768       1030      1499094126          True      0.0    0.0           1
# 1152      1569      1505157817          True     13.0   32.0          54
# 1536      2115      1514552824          True      8.0   21.0          24
# 1920      2619      1523716189          True     15.0   30.0          43
# 2304      3148      1509523187          True     78.0  193.0         198
# 2688      3678      1478948375          True      0.0    0.0           1
# 3072      4215      1524835164         False     36.0   41.0          86
# 3456      4753      1513620114          True      2.0    0.0          10
# 3840      5305      1450094480          True      0.0    0.0           1
# 4224      5847      1476632237          True      8.0    8.0          27
# ...
